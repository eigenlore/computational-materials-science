# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['axes.formatter.useoffset'] = False
KB=0.00008618460742911316
M=11.205e-27 
T_INIT=20
MAX_FORCE=0.01

# %%
input = np.loadtxt("therm_energy_temperature.dat")
time=input[:,0]
energy=input[:,1]
temperature=input[:,2]
plt.plot(time, energy, color='red')
plt.xlabel('Time (s)')
plt.ylabel('Energy (eV)')
plt.title('Energy fluctuations before thermalization')
plt.show()
print("deltaE/E = {:e}".format(np.abs(np.std(energy)/np.mean(energy))))
plt.plot(time, temperature, color='red')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (K)')
plt.title('Temperature fluctuations before thermalization')
plt.show()
print("<T>= ", np.mean(temperature))
# Out:
# deltaE/E = 1.135951e-06
# <T>=  10.039203693689464

# %%
input = np.loadtxt("energy_temperature.dat")
time=input[:,0]
energy=input[:,1]
temperature=input[:,2]
plt.plot(time, energy, color='red')
plt.xlabel('Time (s)')
plt.ylabel('Energy (eV)')
plt.title('Energy fluctuations')
plt.show()
print("deltaE/E = {:e}".format(np.abs(np.std(energy)/np.mean(energy))))
plt.plot(time, temperature, color='red')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (K)')
plt.title('Temperature fluctuations')
plt.show()
print("<T>= ", np.mean(temperature))
# Out:
# deltaE/E = 6.026082e-07
# <T>=  10.057550898192451

# %%
input = np.loadtxt("force_and_U.dat")
force=input[:,0]
U=input[:,1]
plt.plot(force, color='red')
plt.xlabel('Step')
plt.ylabel('Maximum force (eV/A)')
plt.title('Maximum force in steepest descent')
plt.show()
plt.plot(U, color='red')
plt.xlabel('Step')
plt.ylabel('Potential energy (eV)')
plt.title('Potential energy in steepest descent')
plt.show()
